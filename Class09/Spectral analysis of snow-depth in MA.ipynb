# %% [markdown]
# # dimensionality reduction
# ## PCA of Snow Depth in MA

# %%
state='MA'
meas='SNWD'

# %%
# !pip install gdown
# !gdown "https://drive.google.com/uc?export=download&id=1-V87WpiQVRIpZxxAWZ7PpKDBopgoXHeT" -O ../Data/Weather/weather.tgz
# Out:
# Collecting gdown
#   Downloading gdown-5.1.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (from gdown) (4.12.2)
# Collecting filelock (from gdown)
#   Downloading filelock-3.13.4-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.11/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from gdown) (4.66.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests[socks]->gdown) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests[socks]->gdown) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.11/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.1.0-py3-none-any.whl (17 kB)
# Downloading filelock-3.13.4-py3-none-any.whl (11 kB)
# Installing collected packages: filelock, gdown
# Successfully installed filelock-3.13.4 gdown-5.1.0
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1-V87WpiQVRIpZxxAWZ7PpKDBopgoXHeT
# From (redirected): https://drive.google.com/uc?export=download&id=1-V87WpiQVRIpZxxAWZ7PpKDBopgoXHeT&confirm=t&uuid=42da261b-89b1-4e98-a70e-d9ef4ff9a83f
# To: /home/jovyan/Data/Weather/weather.tgz
# 100%|██████████████████████████████████████| 5.59G/5.59G [06:21<00:00, 14.6MB/s]

# %%
# !tar -xzvf ../Data/Weather/weather.tgz -C ../Data/Weather/
# Out:
# weather/
# weather/noaa.tgz
# weather/stations.tgz
# weather/datasets/
# weather/weather.tgz
# weather/datasetsweather-statistics/
# weather/datasetsweather-statistics/NY-SNWD.parquet/
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00009-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00006-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00027-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00014-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00026-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00011-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00005-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00030-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00018-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00001-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00025-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00006-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00020-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00029-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00016-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00017-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00021-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00000-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00002-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00021-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00017-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00030-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00013-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00007-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00033-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00026-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00010-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00022-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00010-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00001-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00031-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00002-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00008-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00015-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00023-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00015-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00027-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00028-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00004-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00009-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00019-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00024-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00007-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00005-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00024-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00019-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00028-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00012-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00033-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00016-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00020-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00003-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00004-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00025-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/_SUCCESS
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00018-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00013-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00031-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00032-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00012-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00003-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00032-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00011-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00022-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00014-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00023-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00029-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasetsweather-statistics/NY-SNWD.parquet/.part-00000-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet.crc
# weather/datasetsweather-statistics/NY-SNWD.parquet/part-00008-62b31c7a-ca4a-42f5-a2b3-327e9cec95fc-c000.snappy.parquet
# weather/datasets/stations-parquet/
# weather/datasets/._.DS_Store
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.FinderInfo'
# weather/datasets/.DS_Store
# weather/datasets/My_Docker_tools/
# weather/datasets/weather_statistics/
# weather/datasets/weather-statistics/
# weather/datasets/weather-parquet/
# weather/datasets/noaa/
# weather/datasets/noaa/readme-by_year.txt
# weather/datasets/noaa/index.html
# weather/datasets/noaa/ghcnd-stations.txt
# weather/datasets/noaa/status-by_year.txt
# weather/datasets/noaa/elaborated_stations.tsv
# weather/datasets/noaa/ghcnd-states.txt
# weather/datasets/noaa/ghcnd-countries.txt
# weather/datasets/noaa/by-year-status.txt
# weather/datasets/noaa/mingle-list.txt
# weather/datasets/noaa/ghcnd-inventory.txt
# weather/datasets/noaa/ghcnd-version.txt
# weather/datasets/noaa/readme.txt
# weather/datasets/noaa/ghcn-daily-by_year-format.rtf
# weather/datasets/noaa/test.txt
# weather/datasets/noaa/status.txt
# weather/datasets/noaa/download.log
# weather/datasets/weather-parquet/part-00028-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00129-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00092-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00037-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00061-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00014-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00114-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00015-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00135-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00073-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00034-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00103-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00141-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00040-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00081-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00009-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00108-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00050-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00120-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00009-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00062-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00112-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00018-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00076-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00002-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00103-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00041-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00131-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00023-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00122-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00083-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00057-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00026-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00096-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00005-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00012-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00113-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00066-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00038-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00061-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00111-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00042-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00132-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00080-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00025-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00086-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00006-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00047-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00033-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00132-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00104-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00005-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00071-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00091-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00034-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00038-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00139-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00017-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00070-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00100-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00019-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00118-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00029-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00091-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00053-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00123-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00050-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00125-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00024-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00067-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00013-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00112-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00099-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00065-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00115-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00046-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00136-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00021-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00084-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00087-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00108-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00078-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00002-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00032-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00133-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00046-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00070-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00105-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00004-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00119-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00069-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00140-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00030-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00095-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00039-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00138-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00013-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00074-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00104-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00090-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00018-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00119-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00088-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00057-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00127-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00124-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00025-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00051-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00033-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00029-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00128-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00096-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00139-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00049-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00115-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00014-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00060-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00010-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00140-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00041-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00134-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00077-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00035-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00107-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00008-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00054-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00109-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00124-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00080-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00066-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00116-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00003-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00102-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00045-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00135-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00077-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00056-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00022-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00022-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00123-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00087-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00001-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00097-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00128-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00058-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00065-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00099-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00093-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00011-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00036-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00110-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00015-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00058-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00102-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00079-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00072-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00085-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00030-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00131-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00044-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00121-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00051-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00008-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00113-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00072-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00063-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00107-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00006-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00019-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00130-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00040-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00092-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00082-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00027-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00126-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00004-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00027-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00053-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00039-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00110-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00060-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00117-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00016-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00062-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00133-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00043-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00081-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00024-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00043-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00136-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00037-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00007-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00082-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00048-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00090-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00035-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00001-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00100-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00075-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00089-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00016-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00101-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00071-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00054-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00020-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00121-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00028-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00122-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00052-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00069-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00095-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00098-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00114-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00064-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00063-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00116-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00017-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00137-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00047-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00020-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/_SUCCESS
# weather/datasets/weather-parquet/.part-00085-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00137-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00036-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00079-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00042-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00109-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00003-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00083-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00068-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00049-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00118-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00031-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00141-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00094-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00074-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00088-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00000-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00101-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00012-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00105-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00075-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00021-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00120-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00055-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00089-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00126-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00056-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00068-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00094-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00010-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00032-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00111-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00064-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00098-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00097-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00048-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00138-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00059-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00011-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00106-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00078-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00076-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00084-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00045-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00125-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00055-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00031-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00130-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00106-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00007-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00117-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00073-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00067-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00134-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00044-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00023-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00093-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00086-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00052-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/part-00127-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00000-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/part-00026-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet
# weather/datasets/weather-parquet/.part-00059-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-parquet/.part-00129-028dcff9-1a94-44cd-9e85-15f7c6967b0c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/MA-TMAX,SNOW,SNWD,TMIN,PRCP,TOBS.pkl
# weather/datasets/weather-statistics/NY-SNWD.pkl
# weather/datasets/weather-statistics/India-TAVG.parquet/
# weather/datasets/weather-statistics/India-TAVG.pkl
# weather/datasets/weather-statistics/VT-TMAX,SNOW,SNWD,TMIN,PRCP,TOBS.pkl
# weather/datasets/weather-statistics/NY-SNWD.parquet/
# weather/datasets/weather-statistics/India-TMAX,TMIN,TAVG.pkl
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00027-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00013-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00006-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00030-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00030-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00002-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00021-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00011-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00001-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00022-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00020-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00001-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00016-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00010-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00033-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00005-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00026-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00021-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00000-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00018-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00009-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00017-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00014-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00026-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00029-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00017-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00007-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00031-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00006-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00025-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00010-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00023-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00012-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00002-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00031-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00003-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00009-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00020-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00015-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00028-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00000-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00024-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00023-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00019-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00005-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00033-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00011-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00012-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00032-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00004-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00025-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00027-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00018-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/_SUCCESS
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00019-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00004-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00032-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00008-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00015-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00013-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00022-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00028-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00003-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00016-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00008-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00007-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/.part-00024-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00014-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/NY-SNWD.parquet/part-00029-7970c511-d744-4267-af41-f8f2388ff52c-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00022-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00019-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00027-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00004-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00003-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00015-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00008-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00029-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00014-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00008-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00018-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00025-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00016-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00028-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00004-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00032-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00024-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00013-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00007-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00019-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00031-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00024-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00012-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00005-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00033-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00020-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00012-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00003-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00023-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00023-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00000-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00002-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00032-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00011-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00009-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00028-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00015-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00018-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00026-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00026-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00007-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00005-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00031-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00014-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00010-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00009-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00021-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00017-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00029-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00000-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00025-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00006-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00017-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00020-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00030-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00013-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/_SUCCESS
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00001-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00021-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00002-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00016-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00027-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00006-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00022-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00001-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00033-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/.part-00010-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet.crc
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00030-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/weather-statistics/India-TAVG.parquet/part-00011-a11160ad-59f9-4283-9fc5-4411863d66ef-c000.snappy.parquet
# weather/datasets/My_Docker_tools/._build.sh
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.lastuseddate#PS'
# weather/datasets/My_Docker_tools/build.sh
# weather/datasets/stations-parquet/.part-00004-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet.crc
# weather/datasets/stations-parquet/part-00000-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet
# weather/datasets/stations-parquet/part-00007-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet
# weather/datasets/stations-parquet/.part-00007-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet.crc
# weather/datasets/stations-parquet/part-00006-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet
# weather/datasets/stations-parquet/.part-00003-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet.crc
# weather/datasets/stations-parquet/.part-00000-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet.crc
# weather/datasets/stations-parquet/part-00001-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet
# weather/datasets/stations-parquet/part-00004-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet
# weather/datasets/stations-parquet/.part-00005-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet.crc
# weather/datasets/stations-parquet/part-00003-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet
# weather/datasets/stations-parquet/.part-00006-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet.crc
# weather/datasets/stations-parquet/_SUCCESS
# weather/datasets/stations-parquet/part-00002-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet
# weather/datasets/stations-parquet/.part-00002-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet.crc
# weather/datasets/stations-parquet/part-00005-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet
# weather/datasets/stations-parquet/.part-00001-5cddd23c-f66a-4c4e-a0d0-93d8239dd5ca-c000.snappy.parquet.crc

# %% [markdown]
# ## Loading libraries and data
# ### Load the required libraries

# %%
#sc.stop()

# %%
# %%time
# %run lib/startup.py
# Out:
# 172.17.0.2
# sparkContext= <SparkContext master=local[2] appName=pyspark-shell>
# /usr/local/spark/python/pyspark/sql/context.py:113: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
#     pandas as    pd 	version=2.0.3 	required version>=0.19.2
#
#      numpy as    np 	version=1.24.4 	required version>=1.12.0
#
#    sklearn as    sk 	version=1.3.1 	required version>=0.18.1
#
# module urllib has no version
#    pyspark as pyspark 	version=3.5.0 	required version>=2.1.0
#
# ipywidgets as ipywidgets 	version=8.1.1 	required version>=6.0.0
#
# version of ipwidgets= 8.1.1
# measurements is a Dataframe (and table) with 12720632 records
# stations is a Dataframe (and table) with 119503 records
# weather is a Dataframe (and table) which is a join of measurements and stations with 12720632 records
# CPU times: user 7.49 s, sys: 1.09 s, total: 8.58 s
# Wall time: 1min 9s

# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%time
weather=measurements.join(stations,on='station')
weather.show(3)

sqlContext.registerDataFrameAsTable(weather,'weather')
# Out:
# +-----------+-----------+----+--------------------+--------+---------+---------+------------+-------------------+-----+-------+
# |    Station|Measurement|Year|              Values|latitude|longitude|elevation|  dist2coast|               name|state|country|
# +-----------+-----------+----+--------------------+--------+---------+---------+------------+-------------------+-----+-------+
# |AG000060390|       TAVG|2022|[79 00 6C 00 66 0...| 36.7167|     3.25|     24.0|   8.0234375| ALGER-DAR EL BEIDA|     |Algeria|
# |AGE00147716|       TAVG|2022|[85 00 83 00 7C 0...|    35.1|    -1.85|     83.0|0.5224609375|NEMOURS (GHAZAOUET)|     |Algeria|
# |AGM00060360|       TMIN|2022|[5A 00 19 FC 4B 0...|  36.822|    7.809|      4.9|  3.16015625|             ANNABA|     |Algeria|
# +-----------+-----------+----+--------------------+--------+---------+---------+------------+-------------------+-----+-------+
# only showing top 3 rows
#
# CPU times: user 2.54 ms, sys: 13.2 ms, total: 15.7 ms
# Wall time: 4.24 s

# %%
ms=['TMAX', 'SNOW', 'SNWD', 'TMIN', 'PRCP', 'TOBS']
# ms=['TMAX', 'TMIN', 'TOBS']
cms='or\n'.join(['Measurement="%s" '%(m) for m in ms])

##  read all data for state
Query="""
SELECT *
FROM weather
WHERE state="%s" and 
(%s)
"""%(state,cms)
print(Query)

#%%time
weather_df=sqlContext.sql(Query)
print('number of rows in result=',weather_df.count())
weather_df.show(2)
# Out:
# SELECT *
# FROM weather
# WHERE state="MA" and
# (Measurement="TMAX" or
# Measurement="SNOW" or
# Measurement="SNWD" or
# Measurement="TMIN" or
# Measurement="PRCP" or
# Measurement="TOBS" )
#
# number of rows in result= 49710
# +-----------+-----------+----+--------------------+--------+---------+---------+-------------+--------------------+-----+-------------+
# |    Station|Measurement|Year|              Values|latitude|longitude|elevation|   dist2coast|                name|state|      country|
# +-----------+-----------+----+--------------------+--------+---------+---------+-------------+--------------------+-----+-------------+
# |US1MABA0017|       PRCP|2022|[00 00 77 00 00 0...| 41.5828| -70.5803|     12.8| 0.9072265625|EAST FALMOUTH 1.2...|   MA|United States|
# |US1MABA0018|       SNOW|2022|[00 00 00 00 19 F...| 41.5818| -70.5257|      9.8|0.94091796875|     WAQUOIT 0.6 SSW|   MA|United States|
# +-----------+-----------+----+--------------------+--------+---------+---------+-------------+--------------------+-----+-------------+
# only showing top 2 rows

# %% [markdown]
# ### Read or compute Statistics File

# %%
### read or compute statistics information for state.

import os.path
from lib.computeStatistics import computeStatistics
from pickle import dump,load

pkl_filename=parquet_root+'weather-statistics/'+state+'-'+','.join(ms)+'.pkl'
print(pkl_filename)
# !ls $pkl_filename
# Out:
# ../Data/Weather/weather/datasets/weather-statistics/MA-TMAX,SNOW,SNWD,TMIN,PRCP,TOBS.pkl
# ../Data/Weather/weather/datasets/weather-statistics/MA-TMAX,SNOW,SNWD,TMIN,PRCP,TOBS.pkl

# %%
if os.path.isfile(pkl_filename):   
    print('precomputed statistics file exists')
    with open(pkl_filename,'br') as pkl_file:
        stat=load(pkl_file)
else:
    print('computing statistics')
    stat=computeStatistics(sqlContext,weather_df,measurements=ms)
    with open(pkl_filename,'bw') as pkl_file:
        dump(stat,pkl_file)
STAT=stat
stat.keys()
# Out:
# precomputed statistics file exists
# dict_keys(['TMAX', 'SNOW', 'SNWD', 'TMIN', 'PRCP', 'TOBS'])

# %% [markdown]
# ## Compute sequence of residuals
#
# Residuals are the remainder left after successive approximations:
# 1) Original vector = $\vec{v}$

# %% [markdown]
# 2) $\vec{r}_0=\vec{v}-\vec{\mu}$

# %% [markdown]
# 3) $\vec{r}_1=\vec{r}_0-(\vec{v}\cdot \vec{u}_1) \vec{u}_1$

# %% [markdown]
# 4) $\vec{r}_2=\vec{r}_1-(\vec{v}\cdot \vec{u}_2) \vec{u}_2$

# %% [markdown]
# 5) $\vec{r}_3=\vec{r}_0-(\vec{v}\cdot \vec{u}_3) \vec{u}_3$
# 6) ......

# %% [markdown]
# For each reidual $\vec{r}_i$ we compute it's square norm, which we will refer to as **residual norm** :
# $$\|\vec{r}_i\|_2^2 = \sum_{j=1}^n (r_{i,j})^2$$
# The smaller tha norm, the better the approximation.

# %% [markdown]
# #### A few things we know from linear algebra:
#
# 1) The zero'th residual norm is the square distance of $\vec{v}$ from the mean $\vec{\mu}$

# %% [markdown]
# 2) The $k$'th residual norm is the minimal square between $\vec{v}$ and a point that can be exspressed as
# $$ \vec{w}_k = \vec{\mu} + \sum_{i=1}^k c_i \vec{u}_i$$
# Where $c_1,\ldots,c_k$ are arbitrary real numbers. We call $\vec{w}_k$ the $k$'th approximation or reconstruction of $\vec{v}$.

# %% [markdown]
# 3) The residual norms are non-increasing.
# 4) The residual vector $\vec{r}_n$ is the zero vector. In other words, $\vec{w}_n = \vec{v}$.

# %% [markdown]
# `decompose_dataframe` axtracts the series from the row, computes the `k` to decomposition coefficients and
# the square norm of the residuals and constructs a new row that is reassembled into a new dataframe.
#
# For more details, use `%load lib/decomposer.py`

# %% [markdown]
# ### Lets do some decompositions!

# %%
m='SNWD'
state='MA'

# %%
# %%time
#get mean and eigenvectors for measurement m
EigVec=STAT[m]['eigvec']
Mean=STAT[m]['Mean']
EigVec.shape

Query="""
select *
from weather
WHERE state='%s' and measurement='%s'
"""%(state,m)
df=sqlContext.sql(Query)
print('number of records=',df.count())
df.show(3)


k=5
df2=decompose_dataframe(sqlContext,df,EigVec[:,:k],Mean).cache() # Make it possible to generate only first k coefficients.
# Out:
# number of records= 8750
# +-----------+-----------+----+--------------------+--------+---------+---------+-------------+-----------------+-----+-------------+
# |    Station|Measurement|Year|              Values|latitude|longitude|elevation|   dist2coast|             name|state|      country|
# +-----------+-----------+----+--------------------+--------+---------+---------+-------------+-----------------+-----+-------------+
# |US1MABA0018|       SNWD|2022|[00 00 00 00 19 F...| 41.5818| -70.5257|      9.8|0.94091796875|  WAQUOIT 0.6 SSW|   MA|United States|
# |US1MABA0060|       SNWD|2022|[00 00 00 00 00 0...| 41.6581| -70.3077|     14.0|  2.849609375|  HYANNIS 0.7 WNW|   MA|United States|
# |US1MAES0004|       SNWD|2022|[00 00 00 00 00 0...| 42.7471| -71.0426|      8.2|          NaN|GROVELAND 0.5 WSW|   MA|United States|
# +-----------+-----------+----+--------------------+--------+---------+---------+-------------+-----------------+-----+-------------+
# only showing top 3 rows
#
# CPU times: user 46.2 ms, sys: 16.3 ms, total: 62.5 ms
# Wall time: 12.1 s

# %%
# %%time
print(df2.count())
# Out:
# 8750
# CPU times: user 40.5 ms, sys: 12.1 ms, total: 52.7 ms
# Wall time: 51.8 s

# %% [markdown]
# ### Join decomposition information with station information

# %%
col=df2.columns

Dcol={}
Dcol['station,year,measurement info']=col[:4]+col[9:14]+[col[21]]
Dcol['coeff']=col[4:9]
Dcol['residuals']=[col[22]]+[col[20]]+col[15:20]
for key in Dcol:
    print('==',key,'==')
    print(','.join(Dcol[key]))
# Out:
# == station,year,measurement info ==
# Station,Measurement,Year,Values,state,country,total_var,res_mean,res_1,res_5
# == coeff ==
# latitude,longitude,elevation,dist2coast,name
# == residuals ==
# coeff_5,coeff_4,res_2,coeff_2,res_3,coeff_3,res_4

# %% [markdown]
# ### Removing years with little snow
# In some locations and in some year, there is almost no snow accumulation. We want to treat these separately.
#
# To do so we compare the error of using the average to the error of using a zero vector. We keep only those yearXstation where the mean is a better approximation than the zero Vector

# %%
# %%time
#filter out vectors for which the mean is a worse approximation than zero.
print('all Rows',df2.count())
df3=df2.filter(df2.res_mean<1)
print('Rows where mean is better approx than zero',df3.count())
# Out:
# all Rows 8750
# Rows where mean is better approx than zero 4172
# CPU times: user 14.9 ms, sys: 15.1 ms, total: 30 ms
# Wall time: 864 ms

# %% [markdown]
# ## Plot mean and top eigenvectors
#
# Construct approximations of a time series using the mean and the $k$ top eigen-vectors
# First, we plot the mean and the top $k$ eigenvectors

# %%
import pylab as plt
fig,axes=plt.subplots(2,1, sharex='col', sharey='row',figsize=(10,10));
k=3
EigVec=np.array(STAT[m]['eigvec'][:,:k])
Mean=STAT[m]['Mean']
YearPlotter().plot(Mean,fig,axes[0],label='Mean',title=m+' Mean')
YearPlotter().plot(EigVec,fig,axes[1],title=m+' Eigs',labels=['eig'+str(i+1) for i in range(k)])
fig.savefig('r_figures/SNWD_mean_eigs')

# %% [markdown]
# ## plot Percentage of variance explained

# %%
#  x=0 in the graphs below correspond to the fraction of the variance explained by the mean alone
#  x=1,2,3,... are the residuals for eig1, eig1+eig2, eig1+eig2+eig3 ...
fig,ax=plt.subplots(1,1);
eigvals=STAT[m]['eigval']; eigvals/=sum(eigvals); cumvar=np.cumsum(eigvals); cumvar=100*np.insert(cumvar,0,0)
ax.plot(cumvar[:10]); 
ax.grid(); 
ax.set_ylabel('Percent of variance explained')
ax.set_xlabel('number of eigenvectors')
ax.set_title('Percent of variance explained');

# %% [markdown]
# ## Exploring the decomposition

# %% [markdown]
# ### Intuitive analysis

# %%
#combine mean with Eigvecs and scale to similar range.
print(EigVec.shape)
_norm_Mean=Mean/max(Mean)*0.2
A=[_norm_Mean]+[EigVec[:,i] for i in range(EigVec.shape[1])]
Combined=np.stack(A).transpose()
# Out:
# (366, 3)

# %%
import pylab as plt
fig,axes=plt.subplots(1,1, sharex='col', sharey='row',figsize=(10,5));
k=3
EigVec=np.array(STAT[m]['eigvec'][:,:k])
Mean=STAT[m]['Mean']
#YearPlotter().plot(Mean,fig,axes[0],label='Mean',title=m+' Mean')
YearPlotter().plot(Combined,fig,axes,title=m+' Eigs',labels=['Mean']+['eig'+str(i+1) for i in range(k)])

# %% [markdown]
# * **Eig1** is very similar to the Mean --- Indicates heavy/light snow
# * If **coef_1** is large: snow accumulation is higher.

# %% [markdown]
# * **Eig2** is negative january, positive march. Indicates early vs. late season
# * If **coef_2** is high: snow season is late.

# %% [markdown]
# * **Eig3** is positive Feb, negative Jan, March -- Indicates a short or long season.
# * If **Coef_3** is high: Season is short.

# %% [markdown]
# ### Studying the effect of Coefficient 1

# %%
# Checking that res_2 is smaller than 0.1 and that rows are sorted based on coeff_2
df4=df2.filter(df2.res_1<0.1).sort(df2.coeff_1)
print(df4.count())
coeff1_rows=df4.collect()
rows=coeff1_rows[:12]
# Out:
# 241

# %%
df4.select('coeff_1','coeff_2','coeff_3','res_1','res_2','res_3',).show(n=4,truncate=14)
# Out:
# +--------------+--------------+--------------+--------------+--------------+--------------+
# |       coeff_1|       coeff_2|       coeff_3|         res_1|         res_2|         res_3|
# +--------------+--------------+--------------+--------------+--------------+--------------+
# |-1003.96473...|122.1904414...|59.06081741...|0.045953264...|0.031749198...|0.028274253...|
# |-1003.96473...|122.1904414...|59.06081741...|0.045953264...|0.031749198...|0.028274253...|
# |-1003.96152...|121.3460782...|54.50636963...|0.044944415...|0.030897039...|0.027799273...|
# |-1003.96152...|121.3460782...|54.50636963...|0.044944415...|0.030897039...|0.027799273...|
# +--------------+--------------+--------------+--------------+--------------+--------------+
# only showing top 4 rows

# %%
plot_recon_grid(coeff1_rows[0:12],Mean,EigVec,header='c1=%3.2f,r1=%3.2f',params=('coeff_1','res_1'))

# %%
plot_recon_grid(coeff1_rows[-12:],Mean,EigVec,header='c1=%3.2f,r1=%3.2f',params=('coeff_1','res_1'))

# %% [markdown]
# ### Studying the effect of Coefficient 2

# %%
# Checking that res_2 is smaller than 0.1 and that rows are sorted based on coeff_2
df4=df2.filter(df2.res_2<0.1).sort(df2.coeff_2)
print(df4.count())
coeff2_rows=df4.collect()
rows=coeff2_rows[:12]
# Out:
# 354

# %%
df4.select('coeff_1','coeff_2','coeff_3','res_1','res_2','res_3',).show(n=4,truncate=14)
# Out:
# +--------------+--------------+--------------+--------------+--------------+--------------+
# |       coeff_1|       coeff_2|       coeff_3|         res_1|         res_2|         res_3|
# +--------------+--------------+--------------+--------------+--------------+--------------+
# |4669.911393...|-2854.73871...|212.3300801...|0.337034996...|0.090424964...|0.089186776...|
# |4414.914018...|-2629.86548...|354.4145977...|0.278723925...|0.048887022...|0.044874400...|
# |3044.966024...|-2584.72806...|-86.5652329...|0.460027113...|0.070949028...|0.070512619...|
# |8642.004188...|-2258.48545...|1122.222425...|0.091368165...|0.037353296...|0.025544162...|
# +--------------+--------------+--------------+--------------+--------------+--------------+
# only showing top 4 rows

# %%
plot_recon_grid(coeff2_rows[:12],Mean,EigVec,header='c2=%3.2f,r2=%3.2f',params=('coeff_2','res_2'))

# %%
plot_recon_grid(coeff2_rows[-12:],Mean,EigVec,header='c2=%3.2f,r2=%3.2f',params=('coeff_2','res_2'))

# %% [markdown]
# ### Studying the effect of Coefficient 3

# %%
df4=df2.filter(df2.res_3<0.1).sort(df2.coeff_3)
print(df4.count())
coeff3_rows=df4.collect()
rows=coeff3_rows[:12]
# Out:
# 536

# %%
df4.select('coeff_1','coeff_2','coeff_3','res_1','res_2','res_3',).show(n=4,truncate=14)
# Out:
# +--------------+--------------+--------------+--------------+--------------+--------------+
# |       coeff_1|       coeff_2|       coeff_3|         res_1|         res_2|         res_3|
# +--------------+--------------+--------------+--------------+--------------+--------------+
# |5102.441575...|-4033.76484...|-4123.28976...|0.592758773...|0.337794087...|0.063099711...|
# |6874.374644...|1917.890071...|-2896.74815...|0.270694911...|0.214027348...|0.081676464...|
# |8371.379532...|2863.455759...|-1692.09903...|0.156907317...|0.058389727...|0.023210721...|
# |2181.687038...|1690.824113...|-1612.91537...|0.572272402...|0.315385046...|0.078044014...|
# +--------------+--------------+--------------+--------------+--------------+--------------+
# only showing top 4 rows

# %%
plot_recon_grid(coeff3_rows[:12],Mean,EigVec,header='c3=%3.2f,r3=%3.2f',params=('coeff_3','res_3'))

# %%
plot_recon_grid(coeff3_rows[-12:],Mean,EigVec)

# %% [markdown]
# ### Best Fit
#
# First, lets plot the SNWD sequences which are best approximated using the first three eigen-vectors.
#
# In other words, the sequences for which the third residual is smallest.
#
# We restrict ourselves to vectors where the first coefficient is positive: overall snow higher then mean.
#
# We can think of these as **architypical** sequences.

# %%
df4=df2.filter(df2.coeff_1>0).sort(df2.res_3)
print(df4.count())
best_fit_rows=df4.collect()
df4.select('coeff_1','coeff_2','coeff_3','res_3').show(n=4,truncate=14)
# Out:
# 2562
# +--------------+--------------+--------------+--------------+
# |       coeff_1|       coeff_2|       coeff_3|         res_3|
# +--------------+--------------+--------------+--------------+
# |3771.383300...|2218.617435...|895.0109171...|0.022064114...|
# |4279.864039...|2406.983713...|1190.486916...|0.022431796...|
# |8371.379532...|2863.455759...|-1692.09903...|0.023210721...|
# |4294.816596...|2412.495113...|1207.141748...|0.023395275...|
# +--------------+--------------+--------------+--------------+
# only showing top 4 rows

# %%
plot_recon_grid(best_fit_rows[:12],Mean,EigVec,header='res_3=%3.2f', params=('res_3',))

# %% [markdown]
# ## worst fit
#
# Next, lets look at the sequence whose third residual is largest.
#
# We can think of those as **outliers** or **noise**. These seuqnces do not fit our model.
#
# Have many of these outliers is a problem: we are either getting poor data, or else our model is inadequate.

# %%
bad_rows=best_fit_rows[-104:-100]+best_fit_rows[-504:-500]+best_fit_rows[-1004:-1000]
plot_recon_grid(bad_rows,Mean,EigVec,header='res_3=%3.2f', params=('res_3',))

# %% [markdown]
# ### Something to try
# Clearly, the majority of the poor fits are a result of undefined entries in the data.
# Can you change the command to focus on years where most of the measurements are defined?

# %% [markdown]
# ## Interactive reconstruction
#
# Following is an interactive widget which lets you change the coefficients of the eigen-vectors to see the effect on the approximation.
# The initial state of the sliders (in the middle) corresponds to the optimal setting. You can zero a positive coefficient by moving the slider all the way down, zero a negative coefficient by moving it all the way up.

# %%
def create_interactive(row):
    target=np.array(unpackArray(row.Values,np.int16),dtype=np.float64)
    eigen_decomp=Eigen_decomp(None,target,Mean,EigVec)
    total_var,residuals,coeff=eigen_decomp.compute_var_explained()
    res=residuals[1]
    print('residual normalized norm  after mean:',res[0])
    print('residual normalized norm  after mean + top eigs:',res[1:])

    plotter=recon_plot(eigen_decomp,year_axis=True,interactive=True)
    display(plotter.get_Interactive())

# %%
create_interactive(coeff3_rows[100])
# Out:
# residual normalized norm  after mean: inf
# residual normalized norm  after mean + top eigs: [0.09999366 0.08752098 0.09270723]
# VBox(children=(HBox(children=(FloatSlider(value=0.0, description='c0', max=0.0, min=-779.4893130731264, orient…

# %%
create_interactive(coeff3_rows[-1])
# Out:
# residual normalized norm  after mean: 0.7360576917711926
# residual normalized norm  after mean + top eigs: [0.30434628 0.24886444 0.06216504]
# VBox(children=(HBox(children=(FloatSlider(value=0.0, description='c0', max=4189.874350516435, orientation='ver…

# %%
create_interactive(coeff3_rows[-50])
# Out:
# residual normalized norm  after mean: 0.6735740247128584
# residual normalized norm  after mean + top eigs: [0.12146204 0.10126608 0.05158754]
# VBox(children=(HBox(children=(FloatSlider(value=0.0, description='c0', max=4048.075571712153, orientation='ver…

# %% [markdown]
# ## Studying the distribution of the coefficients.
#
# Coeff_1-3 capture most of the variance in the snow-depth distribution.
#
# We can now look at how these coefficients vary from year to year.

# %%
pdf=df3.select(['Station','Year','coeff_1','coeff_2','coeff_3','res_1','res_2','res_3','res_mean','total_var']).toPandas()

# %%
#coeff_1 corresponds to the overall amount of snow. 
# 2001,2011, 2015 were heavy snow years
pdf[['Year','coeff_1']][pdf['Year']>2000].boxplot(by='Year',figsize=[15,10]);

# %%
#coeff_2 corresponds to whether the snow was early or late
# 2011 was early 2015 was late
pdf[['Year','coeff_2']][pdf['Year']>2000].boxplot(by='Year',figsize=[15,10]);

# %%
#coeff_2 corresponds to whether the snow season was short or long
# both 2011 and 2015 were long
pdf[['Year','coeff_3']][pdf['Year']>2000].boxplot(by='Year',figsize=[15,10]);

# %%
grpby=pdf.groupby('Year')['coeff_1']
ratio=grpby.mean()/grpby.std()
np.nanmax(ratio),np.nanmin(ratio)
# Out:
# (2.0936501815741684, -3.1381869748531703)

# %%
# A function for plotting the CDF of a given feature
def plot_CDF(feat,power=2):
    rows=df4.select(feat).sort(feat).collect()
    vals=[r[feat]**power for r in rows]
    P=np.arange(0,1,1./(len(vals)+1))
    vals=[vals[0]]+vals
    axis.plot(vals,P,label=feat)

# %%
figure(figsize=(10,8))
axis=gca()

#plot_CDF('res_mean') # why does this not fit?
plot_CDF('res_1')
plot_CDF('res_2')
plot_CDF('res_3')
plot_CDF('res_4')
plot_CDF('res_5')
ylabel('fraction of instances')
xlabel('Residual')
grid()
legend();

# %%
figure(figsize=(10,8))
axis=gca()

plot_CDF('coeff_1',power=1)
plot_CDF('coeff_2',power=1)
plot_CDF('coeff_3',power=1)

ylabel('Prob of being below res value')
xlabel('Residual value')
xlim([-2000,4000])
grid()
legend();
